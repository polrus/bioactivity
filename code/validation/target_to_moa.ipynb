# %%
import pandas as pd

# %%
drug_target_pairs = pd.read_csv("ChEMBL33_CTI_literature_only_full_dataset.csv", sep=";")
drug_target_pairs
# Out:
#         parent_molregno parent_chemblid parent_pref_name  max_phase  \
# 0                100006    CHEMBL303524              NaN        NaN
# 1                100007    CHEMBL304018              NaN        NaN
# 2                100011    CHEMBL305092              NaN        NaN
# 3                100012     CHEMBL65308              NaN        NaN
# 4                100014    CHEMBL303789              NaN        NaN
# ...                 ...             ...              ...        ...
# 646354            99990     CHEMBL62679              NaN        NaN
# 646355            99990     CHEMBL62679              NaN        NaN
# 646356            99991     CHEMBL62731              NaN        NaN
# 646357            99993    CHEMBL435176       SIBRAFIBAN       -1.0
# 646358            99995    CHEMBL423848              NaN        NaN
#
#         first_approval  usan_year  black_box_warning  prodrug  oral  \
# 0                  NaN        NaN                  0       -1     0
# ...
